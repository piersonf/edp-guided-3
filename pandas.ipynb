# %%
import pandas as pd
import numpy as np

# Load the dataset
data = pd.read_csv('troop_movements.csv')

# %%
data.groupby("empire_or_resistance")["empire_or_resistance"].count()
# Out:
# empire_or_resistance
# empire        489
# resistance    511
# Name: empire_or_resistance, dtype: int64

# %%
data.groupby("homeworld")["homeworld"].count()
# Out:
# homeworld
# Alderaan        31
# Aleen Minor     21
# Bestine IV      16
# Cerea           24
# Champala        19
# Chandrila       28
# Concord Dawn    25
# Corellia        21
# Dagobah         18
# Dathomir        24
# Dorin           31
# Eriadu          23
# Glee Anselm     20
# Haruun Kal      25
# Iktotch         29
# Iridonia        18
# Kalee           26
# Kashyyyk        22
# Malastare       27
# Mirial          22
# Mon Cala        21
# Muunilinst      24
# Naboo           32
# Ojom            27
# Quermia         15
# Rodia           17
# Ryloth          25
# Serenno         32
# Shili           26
# Skako           27
# Socorro         30
# Stewjon         22
# Sullust         14
# Tatooine        21
# Tholoth         19
# Toydaria        26
# Trandosha       21
# Troiken         20
# Tund            20
# Umbara          29
# Vulpter         28
# Zolan           34
# Name: homeworld, dtype: int64

# %%
data.groupby("unit_type")["unit_type"].count()
# Out:
# unit_type
# at-at                 111
# at-st                 130
# resistance_soldier    129
# stormtrooper          139
# tie_fighter           126
# tie_silencer          114
# unknown               112
# x-wing                139
# Name: unit_type, dtype: int64

# %%
data['is_resistance'] = data['empire_or_resistance'] == 'resistance'
data
# Out:
#                timestamp  unit_id           unit_type empire_or_resistance  \
# 0    2025-07-08 14:26:41        1               at-st               empire
# 1    2025-07-08 14:26:40        2  resistance_soldier               empire
# 2    2025-07-08 14:26:39        3        tie_silencer           resistance
# 3    2025-07-08 14:26:38        4             unknown           resistance
# 4    2025-07-08 14:26:37        5              x-wing           resistance
# ..                   ...      ...                 ...                  ...
# 995  2025-07-08 14:10:06      996        tie_silencer           resistance
# 996  2025-07-08 14:10:05      997  resistance_soldier               empire
# 997  2025-07-08 14:10:04      998             unknown               empire
# 998  2025-07-08 14:10:03      999        tie_silencer           resistance
# 999  2025-07-08 14:10:02     1000               at-st           resistance
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set Seaborn style
sns.set_theme(style="whitegrid")

# Histogram
plt.figure(figsize=(10, 6))
sns.histplot(data['empire_or_resistance'], kde=False, bins=20, color='red')
plt.title('Character Count By Empire or Resistance')
plt.xlabel('Empire or Resistance')
plt.ylabel('Count')
plt.show()
